# %% [markdown]
# <a href="https://colab.research.google.com/github/AdenMuhammadFaisal/Tugas-Skimage-/blob/main/AdenMuhammadFaisal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import library
import matplotlib.pyplot as plt
# %matplotlib inline

from skimage import data
from skimage.io import imread
from skimage.color import rgb2gray

# %%
original = data.coffee()
print(original.shape)
      
plt.imshow(original)
# Out:
# (400, 600, 3)

# %%
#mengakses channel RGB

red = original [:, :, 0]
green = original[:, :, 1]
blue = original [:, :, 2]

print("Red shape: ",red.shape)
print("Green shape: ",green.shape)
print("Blue shape: ",blue.shape)

fig, axes = plt.subplots(2, 2, figsize=(10,10))
ax = axes.ravel()

ax[0].imshow(original)
ax[0].set_title("Citra Input")

ax[1].imshow(red, cmap=plt.cm.gray)
ax[1].set_title("Red channel")

ax[2].imshow(green, cmap=plt.cm.gray)
ax[2].set_title("Green channel")

ax[3].imshow(blue, cmap=plt.cm.gray)
ax[3].set_title("Blue channel")

fig.tight_layout()
plt.show()
# Out:
# Red shape:  (400, 600)
# Green shape:  (400, 600)
# Blue shape:  (400, 600)

# %%
#mengakses channel RGB versi 2

red = original.copy()
red[:, :, 1]=0
red[:, :, 2]=0
print("Red shape= ",red.shape)

green = original.copy()
green[:, :, 0]=0
green[:, :, 2]=0
print("Green shape= ",green.shape)

blue = original.copy()
blue[:, :, 0]=0
blue[:, :, 1]=0
print("Blue shape= ",blue.shape)

fig, axes = plt.subplots(2, 2, figsize=(10,10))
ax = axes.ravel()

ax[0].imshow(original)
ax[0].set_title("Citra Input")

ax[1].imshow(red)
ax[1].set_title("Red channel")

ax[2].imshow(green)
ax[2].set_title("Green channel")

ax[3].imshow(blue)
ax[3].set_title("Blue channel")

fig.tight_layout()
plt.show()
# Out:
# Red shape=  (400, 600, 3)
# Green shape=  (400, 600, 3)
# Blue shape=  (400, 600, 3)
